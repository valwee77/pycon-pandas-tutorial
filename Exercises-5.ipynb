# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
cast = pd.read_csv('data/cast.csv')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
release_dates = pd.read_csv(
    'data/release_dates.csv',
    parse_dates=['date'],
    infer_datetime_format=True,
)
release_dates.head()
# Out:
# /var/folders/86/0y0_l46d6tq57xc5bxvgdxx80000gn/T/ipykernel_46832/1216377476.py:1: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   release_dates = pd.read_csv(
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                   #BKKY  2016     Cambodia 2017-10-12
# 2                 #Beings  2015      Romania 2015-01-29
# 3               #Captured  2017          USA 2017-09-05
# 4  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21

# %% [markdown]
# ### Make a bar plot of the months in which movies with "Christmas" in their title tend to be released in the USA.

# %%
r = release_dates
r = r[(r.country == 'USA') & (r.title.str.contains('Christmas'))].copy()
r['month'] = r.date.dt.month_name()

month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

r = r.groupby(['month']).size().reindex(month_order)
r.plot(kind='bar', title='Number of Christmas movies released by month in USA')
# Out:
# <Axes: title={'center': 'Number of Christmas movies released by month in USA'}, xlabel='month'>

# %% [markdown]
# ### Make a bar plot of the months in which movies whose titles start with "The Hobbit" are released in the USA.

# %%
r = release_dates
r = r[(r.country == 'USA') & (r.title.str.startswith('The Hobbit'))].copy()

month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

r['month'] = r.date.dt.month_name()
r = r.groupby(['month']).size().reindex(month_order)
r.plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ### Make a bar plot of the day of the week on which movies with "Romance" in their title tend to be released in the USA.

# %%
r = release_dates
r = r[(r.country == 'USA') & (r.title.str.contains('Romance'))].copy()

r['day'] = r.date.dt.day_name()

day_order = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

r = r.groupby('day').size().reindex(day_order)
r.plot(kind='bar',title='Romdance moviews released by day of the week')
# Out:
# <Axes: title={'center': 'Romdance moviews released by day of the week'}, xlabel='day'>

# %% [markdown]
# ### Make a bar plot of the day of the week on which movies with "Action" in their title tend to be released in the USA.

# %%
r = release_dates
r = r[(r.country=='USA') & (r.title.str.contains('Action'))].copy()

day_order = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

r['day'] = r.date.dt.day_name()
r =
# Out:
#                                                     title  year country  \
# 6245                                       A Civil Action  1998     USA
# 8377                                      A Man of Action  1923     USA
# 12909                                       Ace of Action  1926     USA
# 13184                                              Action  1921     USA
# 13191                                       Action Galore  1925     USA
# 13197                                      Action Jackson  1988     USA
# 13220                                        Action Point  2018     USA
# 13225                                        Action Short  2013     USA
# 13228                                  Action for Slander  1937     USA
# 13236                        Action in the North Atlantic  1943     USA
# 13248                                 Action of the Tiger  1957     USA
# 14412                                 After Action Review  2009     USA
# 32544                                      Back in Action  1993     USA
# 49796                     Braddock: Missing in Action III  1988     USA
# 67045                                        Class Action  1991     USA
# 93719                               Double Action Daniels  1925     USA
# 108265                                   Executive Action  1973     USA
# 195255                                   Last Action Hero  1993     USA
# 205419                             Life! Camera Action...  2012     USA
# 209202                       Looney Tunes: Back in Action  2003     USA
# 210595  Lots & Lots of Big Trains: Giant Railroads in ...  2012     USA
# 210600  Lots & Lots of Toy Trains: Model Railroading A...  2003     USA
# 218073                                      Man of Action  1933     USA
# 225174                                      Men of Action  1935     USA
# 229680                                  Missing in Action  1984     USA
# 229697                 Missing in Action 2: The Beginning  1985     USA
# 262052                                 Partners in Action  2002     USA
# 377369  The Oscar Nominated Short Films 2013: Live Action  2013     USA
# 408868                                      Triple Action  1925     USA
# 417271                Untitled Disney Live-Action Project  2020     USA
# 417272                Untitled Disney Live-Action Project  2021     USA
#
#              date        day
# 6245   1999-01-08     Friday
# 8377   1923-06-03     Sunday
# 12909  1926-11-28     Sunday
# 13184  1921-09-12     Monday
# 13191  1925-11-03    Tuesday
# 13197  1988-02-12     Friday
# 13220  2018-03-23     Friday
# 13225  2013-04-29     Monday
# 13228  1938-01-14     Friday
# 13236  1943-06-12   Saturday
# 13248  1957-08-30     Friday
# 14412  2009-11-25  Wednesday
# 32544  1994-07-13  Wednesday
# 49796  1988-01-22     Friday
# 67045  1991-03-15     Friday
# 93719  1925-05-08     Friday
# 108265 1973-11-07  Wednesday
# 195255 1993-06-18     Friday
# 205419 2012-07-20     Friday
# 209202 2003-11-14     Friday
# 210595 2012-01-01     Sunday
# 210600 2003-01-01  Wednesday
# 218073 1933-01-20     Friday
# 225174 1935-07-13   Saturday
# 229680 1984-11-16     Friday
# 229697 1985-03-01     Friday
# 262052 2002-10-31   Thursday
# 377369 2013-02-01     Friday
# 408868 1925-12-20     Sunday
# 417271 2020-04-03     Friday
# 417272 2021-03-12     Friday

# %% [markdown]
# ### On which date was each Judi Dench movie from the 1990s released in the USA?

# %% [markdown]
# ### In which months do films with Judi Dench tend to be released in the USA?

# %% [markdown]
# ### In which months do films with Tom Cruise tend to be released in the USA?
